# %% [markdown]
# Measurements ball on incline

# %%
import numpy as np
import matplotlib.pyplot as pyplot

# %%
setup_length, sig_length=[90.06], [0.05]
setup_height, sig_height=[22.21], [0.05]
ball_diameter=['Big',14.99,'medium', 12.68, 'little', 9.97], [0.01]
rail=[5.89], [0.01]
rail_angle1, sig_rail_angle1=[76.25], [0.5]
reverse_rail_angle1, reverse_sig_rail_angle1=[76.00], [0.5]
rail_angle2, sig_rail_angle2=[76.25], [0.5]
reverse_rail_angle2, reverse_sig_rail_angle2=[76.00], [0.5]


gate1, sig_gate1=[], [0.05]
gate2, sig_gate2=[], []
gate3, sig_gate3=[], []
gate4, sig_gate4=[], []
gate5, sig_gate5=[], []

# %%
58.98-56
# Out:
# 2.979999999999997

# %%
#pendulum

length_tape, sig_tape = [22.1511, ] #m
length_laser, sig_length = [] #to the bottom
length_lod_top, sig_lod_top =[11.43], [0.1] #67.43-56
length_lod, sig_lod =[2.98], [0.1] #58.98

#pendulum period
#pendulum timing precision
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #pendulum
# ----> 3 length_tape, sig_tape = [22.1511, ] #m
#       4 length_laser, sig_length = [] #to the bottom
#       5 length_lod_top, sig_lod_top =[67.43], []
#
# ValueError: not enough values to unpack (expected 2, got 1)
