# %%
gate1, sig_gate1 = [0.1631, 0.1631, 0.1631, 0.1635], [0.0001, 0.0005, 0.0005, 1e-3]
gate2, sig_gate2 = [0.3404, 0.3403, 0.3407, 0.3405], [0.0001, 0.0005, 0.0005, 1e-3]
gate3, sig_gate3 = [0.5216, 0.5218, 0.5218, 0.5218], [0.0001, 0.0005, 0.0005, 1e-3]
gate4, sig_gate4 = [0.7120, 0.7120, 0.7119, 0.7121], [0.0001, 0.0005, 0.0005, 1e-3]
gate5, sig_gate5 = [0.8872, 88.79, 0.8872, 0.8875], [0.0003, 0.0005, 0.0005, 1e-3]

ballS_d, sig_ballS_d = [9.99e-3, 10.00e-3,], [0.5e-3, 1e-3]
ballM_d, sig_ballM_d = [12.70e-3, 12.67e-3,], [0.5e-3, 1e-3]
ballL_d, sig_ballL_d = [14.99e-3, 15.00e-3, ], [0.5e-3, 1e-3]

rail_width, sig_rail_width = [5.98e-3, 6.06e-3], [0.5e-3, 1e-3]
base, sig_base = [0.9004, 0.9005], [0.0003, 1e-3]
height, sig_height = [0.2236, 0.2217], [0.0002, 1e-3]
rail_angle1, sig_rail_angle1 = [13.9, 14.09], [0.1, 1e-2]
rail_angle2, sig_rail_angle2 = [13.7, 13.79], [0.1, 1e-2]
